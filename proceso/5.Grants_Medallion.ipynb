# %% [markdown]
# ##Grants

# %%
# %sql
    
GRANT SELECT ON TABLE catalog_au.silver.POKEMON_ENRIQUECIDO TO `jorgee@osom.biz`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG catalog_au TO `jorgee@osom.biz`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA catalog_au.bronze TO `jorgee@osom.biz`;

# %%
# %sql
    
GRANT CREATE TABLE ON SCHEMA catalog_au.bronze TO `jorgee@osom.biz`;
