# %% [markdown]
# ##Grants

# %%
dbutils.widgets.text("catalogo", "catalog_au")
dbutils.widgets.text("usuario", "jorgee@osom.biz")

# %%
# %sql
GRANT SELECT ON TABLE ${catalogo}.silver.POKEMON_ENRIQUECIDO TO `${usuario}`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG ${catalogo} TO `${usuario}`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA ${catalogo}.bronze TO `${usuario}`;

# %%
# %sql
GRANT CREATE TABLE ON SCHEMA ${catalogo}.bronze TO `${usuario}`;
